# %%
import cv2
import numpy as np
import os.path as osp
import matplotlib.pyplot as plt
from time import time
from PIL import Image, ImageDraw, ImageFont

from core import ObjectDetector, CornerDetector

# %%
dt_vehicle = ObjectDetector('yolov4-default', (608, 608))
dt_plate   = ObjectDetector('yolov4-plate_type', (512, 512))
dt_number  = ObjectDetector('yolov4-plate_number', (416, 416))
dt_corner  = CornerDetector('corner_prediction')
# Out:
# <yolov4-default> model loaded.
# <yolov4-plate_type> model loaded.
# <yolov4-plate_number> model loaded.
# <corner_prediction> model loaded.

# %%
def getPlateNumber(box, ptype, pnumber):
    number = ''
    order = box[:, 0, 0].argsort() # using x1 value to sort
    for o in order:
        number += pnumber[o]
    result = f'{number} ({ptype})'

    return result

def drawRectangle(img, box, color):
    if color == 'red':
        color = (255, 0, 0)
    elif color == 'green':
        color = (0, 255, 0)
    cv2.rectangle(img, (box[0, 0], box[0, 1]), (box[1, 0], box[1, 1]), color, 1)

    return img

def drawPlateNumber(img, result):
    img = cv2.resize(img, (200, 100))
    img = cv2.copyMakeBorder(img, 0, 25, 0, 0, cv2.BORDER_CONSTANT, value=(0, 0, 0))
    img = Image.fromarray(img)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('font/msjh.ttc', 20, encoding='utf-8')
    draw.text((2, img.size[1]-28), result, font=font)
    img = np.array(img)

    return img

# %%
img_dir = 'images/test'
img_file = '35784548.jpg'
img_path = osp.join(img_dir, img_file)

total_time = 0
MULTI_VEHICLES = True

img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
start_time1 = time()
_ = dt_vehicle.loadImage(img)
bbox1, obj1 = dt_vehicle.runDetection('vehicle', 'max_area', MULTI_VEHICLES)
total_time1 = time() - start_time1

if len(bbox1) != 0:
    for box1 in bbox1:
        start_time2 = time()
        img_vehicle = dt_plate.loadImage(img, True, box1)
        bbox2, obj2 = dt_plate.runDetection('plate')

        if len(bbox2) != 0:
            img_plate = dt_corner.loadImage(img_vehicle, True, bbox2)
            img_plate_warped, corner_pts = dt_corner.runDetection()

            _ = dt_number.loadImage(img_plate_warped)
            bbox3, obj3 = dt_number.runDetection('number')

            if len(bbox3) != 0:
                result = getPlateNumber(bbox3, obj2, obj3)
                total_time2 = total_time1 + (time() - start_time2)
                total_time += total_time2
                print('Number (Type): ', result)
                print('Recognition time: {:.3f}s'.format(total_time2))

                img_copy = drawRectangle(img.copy(), box1, 'red')
                pts = np.array([[box1[0, 0]+bbox2[0, 0], box1[0, 1]+bbox2[0, 1]],
                                [box1[0, 0]+bbox2[1, 0], box1[0, 1]+bbox2[1, 1]]])
                img_copy = drawRectangle(img_copy, pts, 'green')              
                img_plate_warped = drawPlateNumber(img_plate_warped, result)
                
                plt.figure(figsize=(12, 7))
                plt.imshow(img_copy)
                plt.figure(figsize=(6, 3))
                plt.imshow(img_plate_warped)
                plt.show()

print('Total Recognition time: {:.3f}s'.format(total_time))
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 2s 2s/step
# Number (Type):  AYC5069 (白底黑字)
# Recognition time: 3.581s
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# Total Recognition time: 3.581s

# %%
dt_corner.printModel()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 128, 3)]      0
#
#  conv2d (Conv2D)             (None, 64, 128, 32)       896
#
#  batch_normalization (BatchN  (None, 64, 128, 32)      128
#  ormalization)
#
#  activation (Activation)     (None, 64, 128, 32)       0
#
#  conv2d_1 (Conv2D)           (None, 64, 128, 32)       9248
#
#  batch_normalization_1 (Batc  (None, 64, 128, 32)      128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64, 128, 32)       0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 32, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 64, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 32, 64, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 32, 64, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 32, 64, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 32, 64, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 64, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 32, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 32, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 32, 32)        18464
#
#  batch_normalization_4 (Batc  (None, 16, 32, 32)       128
#  hNormalization)
#
#  activation_4 (Activation)   (None, 16, 32, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 16, 32, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 16, 32, 64)       256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 32, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 16, 64)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 16, 64)         0
#
#  conv2d_6 (Conv2D)           (None, 8, 16, 32)         18464
#
#  batch_normalization_6 (Batc  (None, 8, 16, 32)        128
#  hNormalization)
#
#  activation_6 (Activation)   (None, 8, 16, 32)         0
#
#  conv2d_7 (Conv2D)           (None, 8, 16, 64)         18496
#
#  batch_normalization_7 (Batc  (None, 8, 16, 64)        256
#  hNormalization)
#
#  activation_7 (Activation)   (None, 8, 16, 64)         0
#
#  conv2d_8 (Conv2D)           (None, 8, 16, 32)         2080
#
#  batch_normalization_8 (Batc  (None, 8, 16, 32)        128
#  hNormalization)
#
#  activation_8 (Activation)   (None, 8, 16, 32)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 8, 32)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 4, 8, 32)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  activation_9 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 8)                 1032
#
#  activation_10 (Activation)  (None, 8)                 0
#
# =================================================================
# Total params: 247,656
# Trainable params: 246,888
# Non-trainable params: 768
# _________________________________________________________________
